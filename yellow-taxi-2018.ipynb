# %%
from __future__  import print_function, division
import pylab as pl
import pandas as pd
import numpy as np
import os

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
puidata = os.getenv("PUIDATA")

# %%
#yellow taxi 2018.1-4月从JFK出发或到达JFK的数据
#df_11 = pd.read_csv(os.getenv("PUIDATA") + '/yellowJan1.csv')
#df_12 = pd.read_csv(os.getenv("PUIDATA") + '/yellowJan2.csv')
#df_21 = pd.read_csv(os.getenv("PUIDATA") + '/yellowFeb1.csv')
#df_22 = pd.read_csv(os.getenv("PUIDATA") + '/yellowFeb2.csv')
#df_31 = pd.read_csv(os.getenv("PUIDATA") + '/yellowMar1.csv')
#df_32 = pd.read_csv(os.getenv("PUIDATA") + '/yellowMar2.csv')
#df_41 = pd.read_csv(os.getenv("PUIDATA") + '/yellowApr1.csv')
#df_42 = pd.read_csv(os.getenv("PUIDATA") + '/yellowApr2.csv')

# %%
#df1 = pd.concat([df_11,df_12])
#df2 = pd.concat([df_21,df_22])
#df3 = pd.concat([df_31,df_32])
#df4 = pd.concat([df_41,df_42])
#df_1 = pd.concat([df1,df2])
#df_2 = pd.concat([df3,df4])
#df = pd.concat([df_1,df_2])
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2        2018/1/1 0:32         2018/1/1 0:59                1
# 1         2        2018/1/1 0:37         2018/1/1 1:24                1
# 2         1        2018/1/1 0:58         2018/1/1 1:35                2
# 3         1        2018/1/1 0:52         2018/1/1 1:28                0
# 4         2        2018/1/1 0:14         2018/1/1 0:50                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          10.66           1                  N           132            61
# 1          22.07           5                  N           132           265
# 2          24.00           1                  N           132           220
# 3          17.90           2                  N           132           262
# 4          13.31           1                  N           132            25
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
#无缺失值
(df.shape[0] - df.count())/(df.shape[0])
# Out:
# VendorID                 0.0
# tpep_pickup_datetime     0.0
# tpep_dropoff_datetime    0.0
# passenger_count          0.0
# trip_distance            0.0
# RatecodeID               0.0
# store_and_fwd_flag       0.0
# PULocationID             0.0
# DOLocationID             0.0
# payment_type             0.0
# fare_amount              0.0
# extra                    0.0
# mta_tax                  0.0
# tip_amount               0.0
# tolls_amount             0.0
# improvement_surcharge    0.0
# total_amount             0.0
# dtype: float64

# %%
df.hist(column='trip_distance')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f132595bc10>]], dtype=object)

# %%
df.hist(column='total_amount')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1324499450>]], dtype=object)

# %%
#df = pd.concat([df1,df2])
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2        2018/1/1 0:32         2018/1/1 0:59                1
# 1         2        2018/1/1 0:37         2018/1/1 1:24                1
# 2         1        2018/1/1 0:58         2018/1/1 1:35                2
# 3         1        2018/1/1 0:52         2018/1/1 1:28                0
# 4         2        2018/1/1 0:14         2018/1/1 0:50                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          10.66           1                  N           132            61
# 1          22.07           5                  N           132           265
# 2          24.00           1                  N           132           220
# 3          17.90           2                  N           132           262
# 4          13.31           1                  N           132            25
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df[df['trip_distance']>=10]
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2        2018/1/1 0:32         2018/1/1 0:59                1
# 1         2        2018/1/1 0:37         2018/1/1 1:24                1
# 2         1        2018/1/1 0:58         2018/1/1 1:35                2
# 3         1        2018/1/1 0:52         2018/1/1 1:28                0
# 4         2        2018/1/1 0:14         2018/1/1 0:50                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          10.66           1                  N           132            61
# 1          22.07           5                  N           132           265
# 2          24.00           1                  N           132           220
# 3          17.90           2                  N           132           262
# 4          13.31           1                  N           132            25
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.to_csv(
    "ML:\df.csv"
)
